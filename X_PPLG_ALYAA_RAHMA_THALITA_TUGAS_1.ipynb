# %% [markdown]
# <a href="https://colab.research.google.com/github/rahmaalyaa29-commits/DasarPPLG-X-2627/blob/main/X_PPLG_ALYAA_RAHMA_THALITA_TUGAS_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tugas 1 praktik membuat variabel variabel dan tipe data
#
# Nama Kelompok: Nexacode
#
# 1.Raisya Putri Darmawan
# 2.Nur Mawadah
# 3.Syafira Meidiana Syarif
# 4.Alyaa Rahma Thalita
# 5.Teuku Muhammad Fadhil
# 6.Davi Ramadhan Pratama
# 7.Aghnan Aiszar Kamaludin

# %%
# %%writefile praktik_variabel.cpp
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main(){
#  //Deklarasi Variabel dan Tipe Data
# string namaBarang= " sepatu adidas ";
# int jumlah = 2;
# float harga = 2900000.50;
# char kategori = 'A';
# bool tersedia = true;
#
# //Menampilkan Output ke Layar
# cout << "=== DATA INVENTARIS ===" << endl;
# cout << "Nama Barang :" << namaBarang << endl;
# cout << "Kategori :" << kategori << endl;
# cout << "Jumlah :" << jumlah << endl;
# cout << "Harga :Rp" << harga << endl;
# cout << "Tersedia :" << tersedia << "(1=Ya, 0=Tidak)" << endl;
# cout << "=======================" << endl;
#
# return 0;
#
# }
# Out:
# Writing praktik_variabel.cpp

# %%
# !g++ praktik_variabel.cpp -o praktik_variabel
# !./praktik_variabel
# Out:
# === DATA INVENTARIS ===
# Nama Barang : sepatu adidas
# Kategori :A
# Jumlah :2
# Harga :Rp2.9e+06
# Tersedia :1(1=Ya, 0=Tidak)
# =======================
